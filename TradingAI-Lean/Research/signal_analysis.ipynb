# %% [markdown]
# # Trading-AI Lean Research Notebook
#
# This notebook provides an interactive environment for analyzing backtest results
# and optimizing Trading-AI model weights.

# %%
import sys
sys.path.insert(0, '../../src')

from lean_bridge import LeanSignalBridge
import pandas as pd
import matplotlib.pyplot as plt

# %%
bridge = LeanSignalBridge()
signals = bridge.journal_to_signals()
signals.head()

# %%
summary = bridge.get_ticker_summary()
for ticker, info in summary.items():
    print(f"{ticker}: {info}")
